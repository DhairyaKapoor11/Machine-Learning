# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Datas/adult.csv')

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K
# 1              50  United-States  <=50K
# 2              40  United-States   >50K
# 3              40  United-States   >50K
# 4              30  United-States  <=50K

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
# age                48842 non-null int64
# workclass          48842 non-null object
# fnlwgt             48842 non-null int64
# education          48842 non-null object
# educational-num    48842 non-null int64
# marital-status     48842 non-null object
# occupation         48842 non-null object
# relationship       48842 non-null object
# race               48842 non-null object
# gender             48842 non-null object
# capital-gain       48842 non-null int64
# capital-loss       48842 non-null int64
# hours-per-week     48842 non-null int64
# native-country     48842 non-null object
# income             48842 non-null object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
df_1 = df[df.workclass == '?']
df_1
# Out:
#        age workclass  fnlwgt     education  educational-num  \
# 4       18         ?  103497  Some-college               10
# 6       29         ?  227026       HS-grad                9
# 13      58         ?  299831       HS-grad                9
# 22      72         ?  132015       7th-8th                4
# 35      65         ?  191846       HS-grad                9
# 75      17         ?  165361          10th                6
# 89      41         ?   38434       Masters               14
# 100     51         ?  189762  Some-college               10
# 113     20         ?   30796       HS-grad                9
# 132     20         ?  334105       HS-grad                9
# 182     28         ?  168524       HS-grad                9
# 185     64         ?  201368  Some-college               10
# 193     79         ?   48574       7th-8th                4
# 228     25         ?  270276           9th                5
# 229     77         ?  172744  Some-college               10
# 245     39         ?  110342       HS-grad                9
# 266     61         ?  195789       HS-grad                9
# 268     21         ?   65481  Some-college               10
# 274     53         ?  237868       HS-grad                9
# 316     20         ?  318865  Some-college               10
# 331     20         ?  303121  Some-college               10
# 350     45         ?  319993       HS-grad                9
# 378     73         ?   73402  Some-college               10
# 394     41         ?  155041       HS-grad                9
# 397     63         ?  156158       HS-grad                9
# 413     22         ?  213291    Assoc-acdm               12
# 429     23         ?  192028  Some-college               10
# 434     19         ?   50626  Some-college               10
# 437     75         ?   26586          10th                6
# 470     19         ?   47235  Some-college               10
# ...    ...       ...     ...           ...              ...
# 48297   62         ?  178764       HS-grad                9
# 48320   24         ?  108495       HS-grad                9
# 48343   26         ?  375313  Some-college               10
# 48351   18         ?   97474       HS-grad                9
# 48354   65         ?  192825       7th-8th                4
# 48356   27         ?  147638       Masters               14
# 48361   21         ?  155697           9th                5
# 48364   51         ?   43909       HS-grad                9
# 48369   21         ?   78374       HS-grad                9
# 48374   62         ?  263374     Assoc-voc               11
# 48384   34         ?  330301       7th-8th                4
# 48470   19         ?  204868       HS-grad                9
# 48482   49         ?  113913       HS-grad                9
# 48487   72         ?   96867       5th-6th                3
# 48556   20         ?   99891  Some-college               10
# 48572   59         ?  120617  Some-college               10
# 48591   21         ?  205939  Some-college               10
# 48598   63         ?  126540  Some-college               10
# 48616   18         ?  156608          11th                7
# 48624   66         ?   93318       HS-grad                9
# 48707   20         ?  203992       HS-grad                9
# 48758   49         ?  114648          12th                8
# 48771   60         ?  134152           9th                5
# 48775   82         ?  403910       HS-grad                9
# 48806   81         ?  120478     Assoc-voc               11
# 48811   35         ?  320084     Bachelors               13
# 48812   30         ?   33811     Bachelors               13
# 48820   71         ?  287372     Doctorate               16
# 48822   41         ?  202822       HS-grad                9
# 48823   72         ?  129912       HS-grad                9
#
#               marital-status occupation    relationship                race  \
# 4              Never-married          ?       Own-child               White
# 6              Never-married          ?       Unmarried               Black
# 13        Married-civ-spouse          ?         Husband               White
# 22                  Divorced          ?   Not-in-family               White
# 35        Married-civ-spouse          ?         Husband               White
# 75             Never-married          ?       Own-child               White
# 89        Married-civ-spouse          ?            Wife               White
# 100       Married-civ-spouse          ?            Wife               White
# 113            Never-married          ?       Own-child               White
# 132            Never-married          ?   Not-in-family               White
# 182       Married-civ-spouse          ?       Own-child               White
# 185       Married-civ-spouse          ?         Husband               White
# 193                  Widowed          ?   Not-in-family               White
# 228                Separated          ?   Not-in-family               White
# 229       Married-civ-spouse          ?         Husband               White
# 245       Married-civ-spouse          ?            Wife               White
# 266       Married-civ-spouse          ?         Husband               White
# 268            Never-married          ?       Own-child               White
# 274       Married-civ-spouse          ?         Husband               White
# 316            Never-married          ?   Not-in-family               White
# 331            Never-married          ?       Own-child               White
# 350                  Widowed          ?       Unmarried               White
# 378       Married-civ-spouse          ?         Husband               White
# 394            Never-married          ?       Own-child               White
# 397       Married-civ-spouse          ?         Husband               White
# 413            Never-married          ?       Own-child               White
# 429            Never-married          ?       Own-child               White
# 434            Never-married          ?       Own-child               Black
# 437    Married-spouse-absent          ?   Not-in-family               White
# 470            Never-married          ?       Own-child               White
# ...                      ...        ...             ...                 ...
# 48297     Married-civ-spouse          ?         Husband               White
# 48320          Never-married          ?       Own-child               White
# 48343          Never-married          ?       Own-child  Asian-Pac-Islander
# 48351          Never-married          ?       Own-child               White
# 48354     Married-civ-spouse          ?         Husband               White
# 48356          Never-married          ?   Not-in-family               Other
# 48361          Never-married          ?       Own-child               White
# 48364               Divorced          ?       Unmarried               Black
# 48369          Never-married          ?  Other-relative  Asian-Pac-Islander
# 48374     Married-civ-spouse          ?         Husband               White
# 48384              Separated          ?       Unmarried               Black
# 48470     Married-civ-spouse          ?            Wife               White
# 48482     Married-civ-spouse          ?            Wife               White
# 48487                Widowed          ?   Not-in-family               White
# 48556          Never-married          ?       Own-child               White
# 48572          Never-married          ?   Not-in-family               Black
# 48591          Never-married          ?       Own-child               White
# 48598               Divorced          ?   Not-in-family               White
# 48616          Never-married          ?       Own-child               White
# 48624                Widowed          ?       Unmarried               White
# 48707          Never-married          ?       Own-child               White
# 48758               Divorced          ?  Other-relative               Black
# 48771               Divorced          ?   Not-in-family               Black
# 48775          Never-married          ?   Not-in-family               White
# 48806               Divorced          ?       Unmarried               White
# 48811     Married-civ-spouse          ?            Wife               White
# 48812          Never-married          ?   Not-in-family  Asian-Pac-Islander
# 48820     Married-civ-spouse          ?         Husband               White
# 48822              Separated          ?   Not-in-family               Black
# 48823     Married-civ-spouse          ?         Husband               White
#
#        gender  capital-gain  capital-loss  hours-per-week native-country  \
# 4      Female             0             0              30  United-States
# 6        Male             0             0              40  United-States
# 13       Male             0             0              35  United-States
# 22     Female             0             0               6  United-States
# 35       Male             0             0              40  United-States
# 75       Male             0             0              40  United-States
# 89     Female          7688             0              10  United-States
# 100    Female             0             0              18  United-States
# 113    Female             0             0              20  United-States
# 132    Female             0             0              40  United-States
# 182    Female             0             0              38  United-States
# 185      Male             0             0               8  United-States
# 193      Male             0             0              40  United-States
# 228    Female          1055             0              40  United-States
# 229      Male             0             0              35  United-States
# 245    Female             0             0              50  United-States
# 266      Male             0             0              40  United-States
# 268    Female             0             0              30  United-States
# 274      Male             0             0              35  United-States
# 316      Male             0             0              40  United-States
# 331      Male             0             0              45  United-States
# 350    Female             0             0              40         Mexico
# 378      Male             0             0              10  United-States
# 394    Female          3418             0              40  United-States
# 397      Male             0             0              16  United-States
# 413      Male             0             0              25  United-States
# 429    Female             0             0              35  United-States
# 434    Female             0             0              20  United-States
# 437    Female             0             0               5  United-States
# 470    Female             0             0              20  United-States
# ...       ...           ...           ...             ...            ...
# 48297    Male             0             0              40  United-States
# 48320    Male             0             0              40  United-States
# 48343    Male             0             0              40    Philippines
# 48351  Female             0             0              20  United-States
# 48354    Male             0             0              25  United-States
# 48356  Female             0             0              40          Japan
# 48361    Male             0             0              42  United-States
# 48364  Female             0             0              40  United-States
# 48369  Female             0             0              24  United-States
# 48374    Male             0             0              40         Canada
# 48384  Female             0             0              40  United-States
# 48470  Female             0             0              36  United-States
# 48482  Female             0             0              60  United-States
# 48487  Female             0             0              40  United-States
# 48556  Female             0             0              30  United-States
# 48572  Female             0             0              40  United-States
# 48591    Male             0             0              40  United-States
# 48598  Female             0             0               5  United-States
# 48616  Female             0             0              25  United-States
# 48624  Female             0             0              40  United-States
# 48707    Male             0             0              40  United-States
# 48758    Male             0             0              40  United-States
# 48771    Male             0             0              35  United-States
# 48775    Male             0             0               3  United-States
# 48806  Female             0             0               1              ?
# 48811  Female             0             0              55  United-States
# 48812  Female             0             0              99  United-States
# 48820    Male             0             0              10  United-States
# 48822  Female             0             0              32  United-States
# 48823    Male             0             0              25  United-States
#
#       income
# 4      <=50K
# 6      <=50K
# 13     <=50K
# 22     <=50K
# 35     <=50K
# 75     <=50K
# 89      >50K
# 100    <=50K
# 113    <=50K
# 132    <=50K
# 182     >50K
# 185    <=50K
# 193    <=50K
# 228    <=50K
# 229    <=50K
# 245    <=50K
# 266    <=50K
# 268    <=50K
# 274     >50K
# 316    <=50K
# 331    <=50K
# 350    <=50K
# 378    <=50K
# 394    <=50K
# 397    <=50K
# 413    <=50K
# 429    <=50K
# 434    <=50K
# 437    <=50K
# 470    <=50K
# ...      ...
# 48297   >50K
# 48320  <=50K
# 48343  <=50K
# 48351  <=50K
# 48354  <=50K
# 48356  <=50K
# 48361  <=50K
# 48364  <=50K
# 48369  <=50K
# 48374  <=50K
# 48384  <=50K
# 48470  <=50K
# 48482  <=50K
# 48487  <=50K
# 48556  <=50K
# 48572  <=50K
# 48591  <=50K
# 48598  <=50K
# 48616  <=50K
# 48624  <=50K
# 48707  <=50K
# 48758  <=50K
# 48771  <=50K
# 48775  <=50K
# 48806  <=50K
# 48811   >50K
# 48812  <=50K
# 48820   >50K
# 48822  <=50K
# 48823  <=50K
#
# [2799 rows x 15 columns]

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2799 entries, 4 to 48823
# Data columns (total 15 columns):
# age                2799 non-null int64
# workclass          2799 non-null object
# fnlwgt             2799 non-null int64
# education          2799 non-null object
# educational-num    2799 non-null int64
# marital-status     2799 non-null object
# occupation         2799 non-null object
# relationship       2799 non-null object
# race               2799 non-null object
# gender             2799 non-null object
# capital-gain       2799 non-null int64
# capital-loss       2799 non-null int64
# hours-per-week     2799 non-null int64
# native-country     2799 non-null object
# income             2799 non-null object
# dtypes: int64(6), object(9)
# memory usage: 349.9+ KB

# %%
df = df[df['workclass'] != '?']
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 5   34    Private  198693          10th                6       Never-married
#
#           occupation   relationship   race gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct      Own-child  Black   Male             0             0
# 1    Farming-fishing        Husband  White   Male             0             0
# 2    Protective-serv        Husband  White   Male             0             0
# 3  Machine-op-inspct        Husband  Black   Male          7688             0
# 5      Other-service  Not-in-family  White   Male             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K
# 1              50  United-States  <=50K
# 2              40  United-States   >50K
# 3              40  United-States   >50K
# 5              30  United-States  <=50K

# %%
df_categorical = df.select_dtypes(include=['object'])

df_categorical.apply(lambda x: x=='?', axis = 0).sum()
# Out:
# workclass           0
# education           0
# marital-status      0
# occupation         10
# relationship        0
# race                0
# gender              0
# native-country    811
# income              0
# dtype: int64

# %%
df = df[df['occupation'] != '?']
df = df[df['native-country'] != '?']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45222 entries, 0 to 48841
# Data columns (total 15 columns):
# age                45222 non-null int64
# workclass          45222 non-null object
# fnlwgt             45222 non-null int64
# education          45222 non-null object
# educational-num    45222 non-null int64
# marital-status     45222 non-null object
# occupation         45222 non-null object
# relationship       45222 non-null object
# race               45222 non-null object
# gender             45222 non-null object
# capital-gain       45222 non-null int64
# capital-loss       45222 non-null int64
# hours-per-week     45222 non-null int64
# native-country     45222 non-null object
# income             45222 non-null object
# dtypes: int64(6), object(9)
# memory usage: 5.5+ MB

# %%
from sklearn import preprocessing

# %%
df_categorical = df.select_dtypes(include = 'object')
df_categorical.head()
# Out:
#    workclass     education      marital-status         occupation  \
# 0    Private          11th       Never-married  Machine-op-inspct
# 1    Private       HS-grad  Married-civ-spouse    Farming-fishing
# 2  Local-gov    Assoc-acdm  Married-civ-spouse    Protective-serv
# 3    Private  Some-college  Married-civ-spouse  Machine-op-inspct
# 5    Private          10th       Never-married      Other-service
#
#     relationship   race gender native-country income
# 0      Own-child  Black   Male  United-States  <=50K
# 1        Husband  White   Male  United-States  <=50K
# 2        Husband  White   Male  United-States   >50K
# 3        Husband  Black   Male  United-States   >50K
# 5  Not-in-family  White   Male  United-States  <=50K

# %%
le = preprocessing.LabelEncoder()
df_categorical = df_categorical.apply(le.fit_transform)
df_categorical.head()
# Out:
#    workclass  education  marital-status  occupation  relationship  race  \
# 0          2          1               4           6             3     2
# 1          2         11               2           4             0     4
# 2          1          7               2          10             0     4
# 3          2         15               2           6             0     2
# 5          2          0               4           7             1     4
#
#    gender  native-country  income
# 0       1              38       0
# 1       1              38       0
# 2       1              38       1
# 3       1              38       1
# 5       1              38       0

# %%
df = df.drop(df_categorical.columns, axis = 1)
df = pd.concat([df, df_categorical], axis = 1)
df.head()
# Out:
#    age  fnlwgt  educational-num  capital-gain  capital-loss  hours-per-week  \
# 0   25  226802                7             0             0              40
# 1   38   89814                9             0             0              50
# 2   28  336951               12             0             0              40
# 3   44  160323               10          7688             0              40
# 5   34  198693                6             0             0              30
#
#    workclass  education  marital-status  occupation  relationship  race  \
# 0          2          1               4           6             3     2
# 1          2         11               2           4             0     4
# 2          1          7               2          10             0     4
# 3          2         15               2           6             0     2
# 5          2          0               4           7             1     4
#
#    gender  native-country  income
# 0       1              38       0
# 1       1              38       0
# 2       1              38       1
# 3       1              38       1
# 5       1              38       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45222 entries, 0 to 48841
# Data columns (total 15 columns):
# age                45222 non-null int64
# fnlwgt             45222 non-null int64
# educational-num    45222 non-null int64
# capital-gain       45222 non-null int64
# capital-loss       45222 non-null int64
# hours-per-week     45222 non-null int64
# workclass          45222 non-null int64
# education          45222 non-null int64
# marital-status     45222 non-null int64
# occupation         45222 non-null int64
# relationship       45222 non-null int64
# race               45222 non-null int64
# gender             45222 non-null int64
# native-country     45222 non-null int64
# income             45222 non-null int64
# dtypes: int64(15)
# memory usage: 5.5 MB

# %%
df['income'] = df['income'].astype('category')

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('income', axis = 1)
y = df['income']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 99)

X_train.head()
# Out:
#        age  fnlwgt  educational-num  capital-gain  capital-loss  \
# 39923   50   45961               13          6849             0
# 19651   38  348739               15             0             0
# 11260   29  198210                9             0             0
# 28311   45  217654               10             0             0
# 48075   30  204470               10             0             0
#
#        hours-per-week  workclass  education  marital-status  occupation  \
# 39923              40          5          9               3           9
# 19651              60          2         14               2           9
# 11260              40          2         11               4          12
# 28311              40          2         15               2           5
# 48075              36          3         15               2           3
#
#        relationship  race  gender  native-country
# 39923             1     4       1              38
# 19651             0     4       1              38
# 11260             4     2       0              38
# 28311             0     4       1              10
# 48075             0     4       1              38

# %%
from sklearn.tree import DecisionTreeClassifier

dt_default = DecisionTreeClassifier(max_depth = 5)
dt_default.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
y_pred_default = dt_default.predict(X_test)
print(classification_report(y_test, y_pred_default))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.87      0.94      0.90     10223
#           1       0.75      0.56      0.64      3344
#
# avg / total       0.84      0.85      0.84     13567

# %%
print(confusion_matrix(y_test, y_pred_default))
print(accuracy_score(y_test, y_pred_default))
# Out:
# [[9611  612]
#  [1468 1876]]
# 0.8466868135918036

# %%
from IPython.display import Image
from sklearn.externals.six import StringIO

# %%
import pydotplus

# %%
import graphviz

# %%
from sklearn.tree import export_graphviz

# %%
features = list(df.columns[1:])
features
# Out:
# ['fnlwgt',
#  'educational-num',
#  'capital-gain',
#  'capital-loss',
#  'hours-per-week',
#  'workclass',
#  'education',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'gender',
#  'native-country',
#  'income']

# %%
dot_data = StringIO()
export_graphviz(dt_default, out_file = dot_data,
                feature_names = features, rounded = True, filled = True)

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV

n_folds = 5

parameters = {'max_depth' : range(1, 40)}

dtree = DecisionTreeClassifier(criterion = "gini",
                              random_state = 100)

tree = GridSearchCV(dtree, parameters,
                   cv = n_folds,
                   scoring = "accuracy")

tree.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=100,
#             splitter='best'),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'max_depth': range(1, 40)}, pre_dispatch='2*n_jobs',
#        refit=True, return_train_score='warn', scoring='accuracy',
#        verbose=0)

# %%
scores = tree.cv_results_
pd.DataFrame(scores).head()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split3_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split4_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.012846      0.002088         0.001603        0.000794
# 1       0.018489      0.000387         0.001201        0.000378
# 2       0.027709      0.006400         0.001425        0.000472
# 3       0.032428      0.002535         0.001248        0.000374
# 4       0.037563      0.001190         0.000995        0.000008
#
#   param_max_depth            params  split0_test_score  split1_test_score  \
# 0               1  {'max_depth': 1}           0.751579           0.751540
# 1               2  {'max_depth': 2}           0.825016           0.819302
# 2               3  {'max_depth': 3}           0.835439           0.833202
# 3               4  {'max_depth': 4}           0.844757           0.840152
# 4               5  {'max_depth': 5}           0.850442           0.846944
#
#    split2_test_score  split3_test_score       ...         mean_test_score  \
# 0           0.751540           0.751540       ...                0.751572
# 1           0.821671           0.821987       ...                0.821671
# 2           0.834781           0.834781       ...                0.834371
# 3           0.843785           0.842995       ...                0.842142
# 4           0.847102           0.848365       ...                0.847986
#
#    std_test_score  rank_test_score  split0_train_score  split1_train_score  \
# 0        0.000046               39            0.751570            0.751580
# 1        0.001927               17            0.820835            0.822263
# 2        0.000820               13            0.834182            0.834742
# 3        0.002189               10            0.844213            0.840270
# 4        0.001332                6            0.848675            0.849076
#
#    split2_train_score  split3_train_score  split4_train_score  \
# 0            0.751580            0.751580            0.751550
# 1            0.821671            0.821592            0.821994
# 2            0.834347            0.834307            0.834630
# 3            0.844614            0.844653            0.840553
# 4            0.850656            0.849431            0.848332
#
#    mean_train_score  std_train_score
# 0          0.751572         0.000012
# 1          0.821671         0.000482
# 2          0.834442         0.000210
# 3          0.842861         0.002008
# 4          0.849234         0.000801
#
# [5 rows x 21 columns]

# %%
plt.figure()
plt.plot(scores["param_max_depth"],
        scores["mean_train_score"],
        label = "training accuracy")

plt.plot(scores["param_max_depth"],
        scores["mean_test_score"],
        label = "test accuracy")



plt.xlabel("Max_depth")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV

n_folds = 5

parameters = {'min_samples_leaf': range(5, 200, 20)}

dtree = DecisionTreeClassifier(criterion = "gini", 
                              random_state = 100)

tree = GridSearchCV(dtree, parameters, 
                   cv = n_folds,
                   scoring = "accuracy")

tree.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=100,
#             splitter='best'),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'min_samples_leaf': range(5, 200, 20)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='accuracy', verbose=0)

# %%
scores = tree.cv_results_
pd.DataFrame(scores).head()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split3_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split4_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.202288      0.014521         0.003130        0.002329
# 1       0.180677      0.005342         0.002899        0.003950
# 2       0.169795      0.003751         0.003006        0.002508
# 3       0.158274      0.003145         0.002861        0.003671
# 4       0.151141      0.004947         0.002337        0.003725
#
#   param_min_samples_leaf                    params  split0_test_score  \
# 0                      5   {'min_samples_leaf': 5}           0.832596
# 1                     25  {'min_samples_leaf': 25}           0.846968
# 2                     45  {'min_samples_leaf': 45}           0.847757
# 3                     65  {'min_samples_leaf': 65}           0.850442
# 4                     85  {'min_samples_leaf': 85}           0.847757
#
#    split1_test_score  split2_test_score  split3_test_score       ...         \
# 0           0.823882           0.828147           0.827831       ...
# 1           0.851998           0.846786           0.845680       ...
# 2           0.855947           0.847417           0.852314       ...
# 3           0.853578           0.847733           0.854525       ...
# 4           0.854051           0.846786           0.852472       ...
#
#    mean_test_score  std_test_score  rank_test_score  split0_train_score  \
# 0         0.827294        0.003211               10            0.914584
# 1         0.847702        0.002205                9            0.870000
# 2         0.850482        0.003235                3            0.863247
# 3         0.851651        0.002404                1            0.859416
# 4         0.850829        0.002964                2            0.856731
#
#    split1_train_score  split2_train_score  split3_train_score  \
# 0            0.914824            0.916364            0.914705
# 1            0.870123            0.870044            0.870716
# 2            0.862660            0.863805            0.862305
# 3            0.857408            0.859738            0.858711
# 4            0.855868            0.856697            0.854881
#
#    split4_train_score  mean_train_score  std_train_score
# 0            0.915893          0.915274         0.000718
# 1            0.870839          0.870344         0.000358
# 2            0.863258          0.863055         0.000521
# 3            0.859348          0.858924         0.000828
# 4            0.855795          0.855994         0.000683
#
# [5 rows x 21 columns]

# %%
plt.figure()
plt.plot(scores["param_min_samples_leaf"],
        scores["mean_train_score"],
        label="training accuracy")
plt.plot(scores["param_min_samples_leaf"],
        scores["mean_test_score"],
        label = "test accuracy")
plt.xlabel("min_samples_leaf")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)

# %%
# Tuning min_samples_split

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV

n_folds = 5

parameters = {'min_samples_split': range(5, 200, 20)}

dtree = DecisionTreeClassifier(criterion = 'gini',
                              random_state = 100)

tree = GridSearchCV(dtree, parameters,
                   cv = n_folds,
                   scoring = "accuracy")

tree.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=100,
#             splitter='best'),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'min_samples_split': range(5, 200, 20)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='accuracy', verbose=0)

# %%
scores = tree.cv_results_
pd.DataFrame(scores).head()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split3_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split4_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.231492      0.007285         0.003298        0.001984
# 1       0.219093      0.006641         0.003222        0.002636
# 2       0.203364      0.012103         0.002888        0.003796
# 3       0.200436      0.012314         0.002375        0.002055
# 4       0.200941      0.009800         0.004198        0.004221
#
#   param_min_samples_split                     params  split0_test_score  \
# 0                       5   {'min_samples_split': 5}           0.816804
# 1                      25  {'min_samples_split': 25}           0.837334
# 2                      45  {'min_samples_split': 45}           0.840967
# 3                      65  {'min_samples_split': 65}           0.842704
# 4                      85  {'min_samples_split': 85}           0.844599
#
#    split1_test_score  split2_test_score  split3_test_score       ...         \
# 0           0.805402           0.814247           0.807929       ...
# 1           0.823409           0.826726           0.831780       ...
# 2           0.833991           0.837308           0.835571       ...
# 3           0.839204           0.844574           0.842995       ...
# 4           0.844574           0.846786           0.845048       ...
#
#    mean_test_score  std_test_score  rank_test_score  split0_train_score  \
# 0         0.811373        0.004159               10            0.970857
# 1         0.829506        0.004751                9            0.908897
# 2         0.837372        0.002462                8            0.890969
# 3         0.841763        0.002133                7            0.882597
# 4         0.844732        0.001317                6            0.879082
#
#    split1_train_score  split2_train_score  split3_train_score  \
# 0            0.970976            0.970068            0.970897
# 1            0.908427            0.909335            0.909572
# 2            0.890460            0.891684            0.892789
# 3            0.883628            0.884023            0.882838
# 4            0.877389            0.878850            0.878218
#
#    split4_train_score  mean_train_score  std_train_score
# 0            0.969595          0.970479         0.000550
# 1            0.909181          0.909082         0.000394
# 2            0.891964          0.891573         0.000806
# 3            0.883475          0.883312         0.000523
# 4            0.878302          0.878368         0.000588
#
# [5 rows x 21 columns]

# %%
plt.figure()
plt.plot(scores["param_min_samples_split"],
        scores["mean_train_score"],
        label = "training accuracy")
plt.plot(scores["param_min_samples_split"],
        scores["mean_test_score"],
        label = "test accuracy")
plt.xlabel("min_samples_split")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)

# %%
# Grid Search to find Optimal Hyper parameters

# %%
param_grid = {
    'max_depth' : range(5, 15, 5),
    'min_samples_leaf' : range(50, 150, 50),
    'min_samples_split': range(50, 150, 50),
    'criterion': ["entropy", "gini"]
}

n_folds = 5

dtree = DecisionTreeClassifier()
grid_search = GridSearchCV(estimator = dtree, param_grid = param_grid,
                          cv = n_folds, verbose = 1)

grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [Parallel(n_jobs=1)]: Done  80 out of  80 | elapsed:   10.1s finished
# GridSearchCV(cv=5, error_score='raise',
#        estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'max_depth': range(5, 15, 5), 'min_samples_leaf': range(50, 150, 50), 'min_samples_split': range(50, 150, 50), 'criterion': ['entropy', 'gini']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=1)

# %%
cv_results = pd.DataFrame(grid_search.cv_results_)
cv_results
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split3_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split4_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.097185      0.004835         0.001028        0.002056
# 1        0.092071      0.007303         0.001522        0.002015
# 2        0.082679      0.005030         0.001603        0.001989
# 3        0.086058      0.006914         0.004070        0.003933
# 4        0.157559      0.005769         0.001851        0.003702
# 5        0.156630      0.007729         0.003963        0.003736
# 6        0.151974      0.002974         0.004303        0.002165
# 7        0.150430      0.002649         0.001855        0.002272
# 8        0.083550      0.003396         0.002755        0.003760
# 9        0.082030      0.001099         0.002768        0.003589
# 10       0.082840      0.002337         0.001346        0.002692
# 11       0.081633      0.001207         0.003618        0.001929
# 12       0.138685      0.001596         0.003624        0.002269
# 13       0.141124      0.001903         0.001057        0.002114
# 14       0.134479      0.002157         0.002198        0.002696
# 15       0.136210      0.003747         0.002787        0.002442
#
#    param_criterion param_max_depth param_min_samples_leaf  \
# 0          entropy               5                     50
# 1          entropy               5                     50
# 2          entropy               5                    100
# 3          entropy               5                    100
# 4          entropy              10                     50
# 5          entropy              10                     50
# 6          entropy              10                    100
# 7          entropy              10                    100
# 8             gini               5                     50
# 9             gini               5                     50
# 10            gini               5                    100
# 11            gini               5                    100
# 12            gini              10                     50
# 13            gini              10                     50
# 14            gini              10                    100
# 15            gini              10                    100
#
#    param_min_samples_split                                             params  \
# 0                       50  {'criterion': 'entropy', 'max_depth': 5, 'min_...
# 1                      100  {'criterion': 'entropy', 'max_depth': 5, 'min_...
# 2                       50  {'criterion': 'entropy', 'max_depth': 5, 'min_...
# 3                      100  {'criterion': 'entropy', 'max_depth': 5, 'min_...
# 4                       50  {'criterion': 'entropy', 'max_depth': 10, 'min...
# 5                      100  {'criterion': 'entropy', 'max_depth': 10, 'min...
# 6                       50  {'criterion': 'entropy', 'max_depth': 10, 'min...
# 7                      100  {'criterion': 'entropy', 'max_depth': 10, 'min...
# 8                       50  {'criterion': 'gini', 'max_depth': 5, 'min_sam...
# 9                      100  {'criterion': 'gini', 'max_depth': 5, 'min_sam...
# 10                      50  {'criterion': 'gini', 'max_depth': 5, 'min_sam...
# 11                     100  {'criterion': 'gini', 'max_depth': 5, 'min_sam...
# 12                      50  {'criterion': 'gini', 'max_depth': 10, 'min_sa...
# 13                     100  {'criterion': 'gini', 'max_depth': 10, 'min_sa...
# 14                      50  {'criterion': 'gini', 'max_depth': 10, 'min_sa...
# 15                     100  {'criterion': 'gini', 'max_depth': 10, 'min_sa...
#
#     split0_test_score       ...         mean_test_score  std_test_score  \
# 0            0.842072       ...                0.846027        0.002077
# 1            0.842072       ...                0.846027        0.002077
# 2            0.842072       ...                0.845964        0.002112
# 3            0.842072       ...                0.845964        0.002112
# 4            0.846810       ...                0.849376        0.002593
# 5            0.846810       ...                0.849376        0.002593
# 6            0.844915       ...                0.848681        0.002749
# 7            0.844915       ...                0.848586        0.002755
# 8            0.850442       ...                0.848334        0.001196
# 9            0.850442       ...                0.848334        0.001196
# 10           0.847757       ...                0.847165        0.000835
# 11           0.847757       ...                0.847165        0.000835
# 12           0.851706       ...                0.851114        0.001678
# 13           0.851706       ...                0.851114        0.001678
# 14           0.845862       ...                0.849281        0.002544
# 15           0.845862       ...                0.849187        0.002567
#
#     rank_test_score  split0_train_score  split1_train_score  \
# 0                13            0.842554            0.848326
# 1                13            0.842554            0.848326
# 2                15            0.842554            0.848010
# 3                15            0.842554            0.848010
# 4                 3            0.854401            0.856105
# 5                 3            0.854401            0.856105
# 6                 7            0.851597            0.852393
# 7                 8            0.851597            0.852393
# 8                 9            0.848517            0.848484
# 9                 9            0.848517            0.848484
# 10               11            0.846859            0.847970
# 11               11            0.846859            0.847970
# 12                1            0.856889            0.856618
# 13                1            0.856889            0.856618
# 14                5            0.852664            0.851919
# 15                6            0.852664            0.851919
#
#     split2_train_score  split3_train_score  split4_train_score  \
# 0             0.848444            0.847457            0.848016
# 1             0.848444            0.847457            0.848016
# 2             0.848049            0.847457            0.847502
# 3             0.848049            0.847457            0.847502
# 4             0.856579            0.856105            0.854965
# 5             0.856579            0.856105            0.854965
# 6             0.852788            0.851998            0.851175
# 7             0.852788            0.851998            0.851175
# 8             0.850340            0.848997            0.848213
# 9             0.850340            0.848997            0.848213
# 10            0.848365            0.847102            0.847502
# 11            0.848365            0.847102            0.847502
# 12            0.857882            0.856579            0.855400
# 13            0.857882            0.856579            0.855400
# 14            0.853104            0.851801            0.851175
# 15            0.853104            0.851801            0.851175
#
#     mean_train_score  std_train_score
# 0           0.846959         0.002229
# 1           0.846959         0.002229
# 2           0.846715         0.002095
# 3           0.846715         0.002095
# 4           0.855631         0.000813
# 5           0.855631         0.000813
# 6           0.851990         0.000569
# 7           0.851990         0.000569
# 8           0.848910         0.000758
# 9           0.848910         0.000758
# 10          0.847560         0.000552
# 11          0.847560         0.000552
# 12          0.856674         0.000793
# 13          0.856674         0.000793
# 14          0.852132         0.000678
# 15          0.852132         0.000678
#
# [16 rows x 24 columns]

# %%
print("best accuracy", grid_search.best_score_)
print(grid_search.best_estimator_)
# Out:
# best accuracy 0.8511135681566893
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=50, min_samples_split=50,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
# Running the model with best parameters obtained from grid search

# %%
clf_gini = DecisionTreeClassifier(criterion = 'gini',
                                 random_state = 100,
                                 max_depth = 10,
                                 min_samples_leaf = 50,
                                 min_samples_split = 50)

clf_gini.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=50, min_samples_split=50,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=100,
#             splitter='best')

# %%
clf_gini.score(X_test, y_test)
# Out:
# 0.8516989754551485

# %%
# Plotting the tree
dot_data = StringIO()
export_graphviz(clf_gini, out_file = dot_data, feature_names = features, filled = True, rounded = True)

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %%
clf_gini = DecisionTreeClassifier(criterion = "gini",
                                 random_state = 100,
                                 max_depth = 3,
                                 min_samples_leaf = 50,
                                 min_samples_split = 50
                                 )

clf_gini.fit(X_train, y_train)

print(clf_gini.score(X_test, y_test))
# Out:
# 0.8344512419842264

# %%
dot_data = StringIO()
export_graphviz(clf_gini, out_file = dot_data, feature_names=features, filled = True, rounded = True)

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %%
# Classification metrics

# %%
from sklearn.metrics import classification_report, confusion_matrix
y_pred = clf_gini.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.85      0.94      0.90     10223
#           1       0.75      0.50      0.60      3344
#
# avg / total       0.83      0.83      0.82     13567

# %%
# Confusion matrix

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[9660  563]
#  [1683 1661]]
