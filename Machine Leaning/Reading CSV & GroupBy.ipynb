# %%
import pandas as pd
df = pd.read_csv('datas/weather_data.csv')

# %%
df
# Out:
#           day  temperature  windspeed  event
# 0  01-01-2017           32          6   Rain
# 1  01-02-2017       -99999          7  Sunny
# 2  01-03-2017           28     -99999   Snow
# 3  01-04-2017       -99999          7      0
# 4  01-05-2017           32     -99999   Rain
# 5  01-06-2017           31          2  Sunny
# 6  01-06-2017           34          5      0

# %%
# pip install openpyxl
df.to_excel('df_x1.xlsx', sheet_name = 'weather_csv')

# %%
# pip install xlrd
df1 = pd.read_excel('df_x1.xlsx')

# %%
df1
# Out:
#    Unnamed: 0         day  temperature  windspeed  event
# 0           0  01-01-2017           32          6   Rain
# 1           1  01-02-2017       -99999          7  Sunny
# 2           2  01-03-2017           28     -99999   Snow
# 3           3  01-04-2017       -99999          7      0
# 4           4  01-05-2017           32     -99999   Rain
# 5           5  01-06-2017           31          2  Sunny
# 6           6  01-06-2017           34          5      0

# %%
df.to_csv('File.csv')

# %%
df.to_csv('File_noindex.csv', index=False)

# %%
df1
# Out:
#    Unnamed: 0         day  temperature  windspeed  event
# 0           0  01-01-2017           32          6   Rain
# 1           1  01-02-2017       -99999          7  Sunny
# 2           2  01-03-2017           28     -99999   Snow
# 3           3  01-04-2017       -99999          7      0
# 4           4  01-05-2017           32     -99999   Rain
# 5           5  01-06-2017           31          2  Sunny
# 6           6  01-06-2017           34          5      0

# %% [markdown]
# # Groupby

# %%
df_group = df1.groupby("event")

# %%
df_group

# %%
for temperature in df_group:
    print(temperature)
# Out:
# ('0',    Unnamed: 0         day  temperature  windspeed event
# 3           3  01-04-2017       -99999          7     0
# 6           6  01-06-2017           34          5     0)
# ('Rain',    Unnamed: 0         day  temperature  windspeed event
# 0           0  01-01-2017           32          6  Rain
# 4           4  01-05-2017           32     -99999  Rain)
# ('Snow',    Unnamed: 0         day  temperature  windspeed event
# 2           2  01-03-2017           28     -99999  Snow)
# ('Sunny',    Unnamed: 0         day  temperature  windspeed  event
# 1           1  01-02-2017       -99999          7  Sunny
# 5           5  01-06-2017           31          2  Sunny)

# %%
df_group.get_group('Rain')
# Out:
#    Unnamed: 0         day  temperature  windspeed event
# 0           0  01-01-2017           32          6  Rain
# 4           4  01-05-2017           32     -99999  Rain

# %%
df_group.describe()
# Out:
#       Unnamed: 0                                           temperature  \
#            count mean       std  min   25%  50%   75%  max       count
# event
# 0            2.0  4.5  2.121320  3.0  3.75  4.5  5.25  6.0         2.0
# Rain         2.0  2.0  2.828427  0.0  1.00  2.0  3.00  4.0         2.0
# Snow         1.0  2.0       NaN  2.0  2.00  2.0  2.00  2.0         1.0
# Sunny        2.0  3.0  2.828427  1.0  2.00  3.0  4.00  5.0         2.0
#
#                 ...                 windspeed                                  \
#           mean  ...       75%   max     count     mean           std      min
# event           ...
# 0     -49982.5  ... -24974.25  34.0       2.0      6.0      1.414214      5.0
# Rain      32.0  ...     32.00  32.0       2.0 -49996.5  70714.213653 -99999.0
# Snow      28.0  ...     28.00  28.0       1.0 -99999.0           NaN -99999.0
# Sunny -49984.0  ... -24976.50  31.0       2.0      4.5      3.535534      2.0
#
#
# ...

# %%
def hot_temp(x):
    return x > 30

# %%
df1['hot_temp'] = df1['temperature'].apply(hot_temp)

# %%
df1
# Out:
#    Unnamed: 0         day  temperature  windspeed  event  hot_temp
# 0           0  01-01-2017           32          6   Rain      True
# 1           1  01-02-2017       -99999          7  Sunny     False
# 2           2  01-03-2017           28     -99999   Snow     False
# 3           3  01-04-2017       -99999          7      0     False
# 4           4  01-05-2017           32     -99999   Rain      True
# 5           5  01-06-2017           31          2  Sunny      True
# 6           6  01-06-2017           34          5      0      True

# %%
df1['hot_temp'] = df1['temperature'].apply(lambda x: x > 30)

# %%
df1
# Out:
#    Unnamed: 0         day  temperature  windspeed  event  hot_temp
# 0           0  01-01-2017           32          6   Rain      True
# 1           1  01-02-2017       -99999          7  Sunny     False
# 2           2  01-03-2017           28     -99999   Snow     False
# 3           3  01-04-2017       -99999          7      0     False
# 4           4  01-05-2017           32     -99999   Rain      True
# 5           5  01-06-2017           31          2  Sunny      True
# 6           6  01-06-2017           34          5      0      True
